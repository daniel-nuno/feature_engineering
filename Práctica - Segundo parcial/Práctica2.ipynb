# %%
import pandas as pd
ruta='/content/drive/MyDrive/Colab Notebooks/ITESO/Ingeniería de características/P2022_MCD3735A/Práctica - Segundo parcial/'

# %%
data=pd.read_excel(ruta+'Datos presas.xlsx')
data.head()
# Out:
#        Fecha  Nivel 1  Nivel 2  Nivel 3  Nivel 4
# 0 2006-01-01   532.88   391.88   182.86    85.68
# 1 2006-01-02   532.87   392.02   182.86    85.80
# 2 2006-01-03   532.80   391.00   182.87    85.70
# 3 2006-01-04   532.72   391.47   182.90    85.85
# 4 2006-01-05   532.70   391.66   182.90    85.92

# %%
data['años']=data['Fecha'].dt.year # Estas variables ya están discretizadas
data.head()
# Out:
#        Fecha  Nivel 1  Nivel 2  Nivel 3  Nivel 4  años
# 0 2006-01-01   532.88   391.88   182.86    85.68  2006
# 1 2006-01-02   532.87   392.02   182.86    85.80  2006
# 2 2006-01-03   532.80   391.00   182.87    85.70  2006
# 3 2006-01-04   532.72   391.47   182.90    85.85  2006
# 4 2006-01-05   532.70   391.66   182.90    85.92  2006

# %%
data.groupby('años').count()
# Out:
#       Fecha  Nivel 1  Nivel 2  Nivel 3  Nivel 4
# años
# 2006    365      365      365      365      365
# 2007    365      365      365      365      365
# 2008    366      366      366      366      366
# 2009    365      365      365      365      365
# 2010    365      365      365      365      365
# 2011    365      365      365      365      365
# 2012    366      366      366      366      366
# 2013    365      365      365      365      365
# 2014    365      365      365      365      365

# %%
data.columns[1:-1] # Primer nivel de iteración
# Out:
# Index(['Nivel 1', 'Nivel 2', 'Nivel 3', 'Nivel 4'], dtype='object')

# %%
data['años'].unique() # Segundo nivel de iteración
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014])

# %%
x=data.groupby('años')['Nivel 1'].get_group(2006)
x=x-x.min()+1 # Desplazamiento
x.plot(grid=True)
